# %%
import numpy as np
import pandas as pd

# %%
import eurostat

# %%
toc_df = eurostat.get_toc_df()

# %%
f = eurostat.subset_toc_df(toc_df, 'fleet')
f.head()
# Out:
#                                                title             code  \
# 5669                                   Fishing fleet       fish_fleet
# 5670  Fishing fleet by age, length and gross tonnage   fish_fleet_alt
# 5671  Fishing fleet by type of gear and engine power    fish_fleet_gp
# 6284   Commercial aircraft fleet by type of aircraft  avia_eq_arc_typ
# 6285    Commercial aircraft fleet by age of aircraft  avia_eq_arc_age
#
#          type last update of data last table structure change data start  \
# 5669   folder
# 5670  dataset          21.10.2019                  26.09.2019       1990
# 5671  dataset          21.10.2019                  02.10.2019       1990
# 6284  dataset          25.09.2019                  27.05.2019       2001
# 6285  dataset          25.09.2019                  27.05.2019       2001
#
#      data end
# 5669
# 5670     2018
# 5671     2018
# 6284     2017
# 6285     2017

# %%
data = pd.DataFrame(eurostat.get_data('demo_r_d2jan'))

# %%
data
# Out:
#           0    1       2         3          4          5          6   \
# 0       unit  sex     age  geo\time     2018.0     2017.0     2016.0
# 1         NR    F   TOTAL        AL  1431715.0  1423050.0  1417141.0
# 2         NR    F   TOTAL       AL0  1431715.0  1423050.0  1417141.0
# 3         NR    F   TOTAL      AL01   405598.0   405835.0   416845.0
# 4         NR    F   TOTAL      AL02   585530.0   574010.0   552949.0
# ...      ...  ...     ...       ...        ...        ...        ...
# 168608    NR    T  Y_OPEN      UKM7      323.0      343.0      342.0
# 168609    NR    T  Y_OPEN      UKM8      210.0      229.0      231.0
# 168610    NR    T  Y_OPEN      UKM9      160.0      159.0      164.0
# 168611    NR    T  Y_OPEN       UKN      282.0      281.0      274.0
# 168612    NR    T  Y_OPEN      UKN0      282.0      281.0      274.0
#
#                7          8          9   ...      23      24      25       26  \
# 0          2015.0     2014.0     2013.0  ...  1999.0  1998.0  1997.0   1996.0
# 1       1424597.0  1430827.0  1437193.0  ...     NaN     NaN     NaN      NaN
# 2       1424597.0  1430827.0  1437193.0  ...     NaN     NaN     NaN      NaN
# 3             NaN        NaN        NaN  ...     NaN     NaN     NaN      NaN
# 4             NaN        NaN        NaN  ...     NaN     NaN     NaN      NaN
# ...           ...        ...        ...  ...     ...     ...     ...      ...
# 168608      333.0      315.0      294.0  ...     NaN     NaN     NaN      NaN
# 168609      229.0      221.0      206.0  ...     NaN     NaN     NaN      NaN
# 168610      166.0      161.0      149.0  ...     NaN     NaN     NaN      NaN
# 168611      265.0      250.0      237.0  ...  7493.0  7449.0  7293.0  18763.0
# 168612      265.0      250.0      237.0  ...  7493.0  7449.0  7293.0  18763.0
#
#              27       28       29       30      31      32
# 0        1995.0   1994.0   1993.0   1992.0  1991.0  1990.0
# 1           NaN      NaN      NaN      NaN     NaN     NaN
# 2           NaN      NaN      NaN      NaN     NaN     NaN
# 3           NaN      NaN      NaN      NaN     NaN     NaN
# 4           NaN      NaN      NaN      NaN     NaN     NaN
# ...         ...      ...      ...      ...     ...     ...
# 168608      NaN      NaN      NaN      NaN     NaN     NaN
# 168609      NaN      NaN      NaN      NaN     NaN     NaN
# 168610      NaN      NaN      NaN      NaN     NaN     NaN
# 168611  18456.0  18214.0  17934.0  17566.0     NaN     NaN
# 168612  18456.0  18214.0  17934.0  17566.0     NaN     NaN
#
# [168613 rows x 33 columns]

# %%
dic = eurostat.get_dic('sex')
dic
# Out:
# {'T': 'Total',
#  'M': 'Males',
#  'F': 'Females',
#  'DIFF': 'Absolute difference between males and females',
#  'NAP': 'Not applicable',
#  'NRP': 'No response',
#  'UNK': 'Unknown'}

# %%
avail_sdmx_df = eurostat.get_avail_sdmx_df()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-278c7e26b61b> in <module>
# ----> 1 avail_sdmx_df = eurostat.get_avail_sdmx_df()
#
# ~/anaconda3/envs/eurostat/lib/python3.8/site-packages/eurostat/eurostat.py in get_avail_sdmx_df()
#     344
#     345     from urllib.request import _opener #load ex-novo the built/modified opener
# --> 346     proxydic = _opener.handle_open['http'][[isinstance(el, ProxyHandler) for el in _opener.handle_open['http']].index(True)].proxies if _opener else None
#     347     estat = Request('ESTAT', timeout = 100., proxies = proxydic)
#     348     df = estat.dataflow().write()['dataflow']
#
# ValueError: True is not in list

# %%
keyword = 'fleet'
subset = eurostat.subset_avail_sdmx_df(avail_sdmx_df, keyword)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-692607166dea> in <module>
#       1 keyword = 'fleet'
# ----> 2 subset = eurostat.subset_avail_sdmx_df(avail_sdmx_df, keyword)
#
# NameError: name 'avail_sdmx_df' is not defined

# %%
eurostat.get_sdmx_dims('DS-066341')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-99942219515b> in <module>
# ----> 1 eurostat.get_sdmx_dims('DS-066341')
#
# ~/anaconda3/envs/eurostat/lib/python3.8/site-packages/eurostat/eurostat.py in get_sdmx_dims(code)
#     210
#     211     from urllib.request import _opener #load ex-novo the built/modified opener
# --> 212     proxydic = _opener.handle_open['http'][[isinstance(el, ProxyHandler) for el in _opener.handle_open['http']].index(True)].proxies if _opener else None
#     213     estat = Request('ESTAT', timeout = 100., proxies = proxydic)
#     214     try:
#
# ValueError: True is not in list

# %%
StartPeriod = 2007
EndPeriod = 2008
filter_pars = {'FREQ': ['A',], 'PRCCODE': ['08111250','08111150']}
data = eurostat.get_sdmx_data('DS-066341', StartPeriod, EndPeriod, filter_pars, flags = False, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-32c26c46f043> in <module>
#       2 EndPeriod = 2008
#       3 filter_pars = {'FREQ': ['A',], 'PRCCODE': ['08111250','08111150']}
# ----> 4 data = eurostat.get_sdmx_data('DS-066341', StartPeriod, EndPeriod, filter_pars, flags = False, verbose=True)
#
# ~/anaconda3/envs/eurostat/lib/python3.8/site-packages/eurostat/eurostat.py in get_sdmx_data(code, StartPeriod, EndPeriod, filter_pars, flags, verbose)
#     270
#     271     from urllib.request import _opener #load ex-novo the built/modified opener
# --> 272     proxydic = _opener.handle_open['http'][[isinstance(el, ProxyHandler) for el in _opener.handle_open['http']].index(True)].proxies if _opener else None
#     273     estat = Request('ESTAT', timeout = 100., proxies = proxydic)
#     274     dims = filter_pars.keys()
#
# ValueError: True is not in list
